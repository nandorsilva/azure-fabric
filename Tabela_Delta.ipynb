# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
df = spark.read.load("abfss://88d42a16-2c0a-495a-97db-34b2c41a2439@onelake.dfs.fabric.microsoft.com/10aa08da-e1b2-4c37-9689-6d5e7643f00c/Files/20260201_produto.csv", format='csv', header=True)


# Save the dataframe as a delta table
df.write.format("delta").saveAsTable("mytable")
# Out:
# StatementMeta(, d69c037f-50ee-4fdb-8d54-332b160a383f, 3, Finished, Available, Finished, False)

# %%
# Criar tabela

from delta.tables import *

DeltaTable.create(spark) \
  .tableName("tbProdutos") \
  .addColumn("Productid", "INT") \
  .addColumn("ProductName", "STRING") \
  .addColumn("Category", "STRING") \
  .addColumn("Price", "FLOAT") \
  .execute()
# Out:
# StatementMeta(, d69c037f-50ee-4fdb-8d54-332b160a383f, 4, Finished, Available, Finished, False)

# %%
# %%sql
#
# CREATE TABLE salesorders
# (
#     Orderid INT NOT NULL,
#     OrderDate TIMESTAMP NOT NULL,
#     CustomerName STRING,
#     SalesTotal FLOAT NOT NULL
# )
# USING DELTA
# Out:
# StatementMeta(, d69c037f-50ee-4fdb-8d54-332b160a383f, 5, Finished, Available, Finished, False)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
# DESCRIBE HISTORY LH_Bronze.dbo.20260201_produto
# Out:
# StatementMeta(, d69c037f-50ee-4fdb-8d54-332b160a383f, 6, Finished, Available, Finished, False)
# <Spark SQL result set with 1 rows and 15 fields>

# %%
# %%sql
# CREATE TABLE partitioned_products (
#     ProductID INTEGER,
#     ProductName STRING,
#     Category STRING,
#     ListPrice DOUBLE
# )
# PARTITIONED BY (Category);
# Out:
# StatementMeta(, d69c037f-50ee-4fdb-8d54-332b160a383f, 7, Finished, Available, Finished, False)
# <Spark SQL result set with 0 rows and 0 fields>
